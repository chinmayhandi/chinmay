# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmayhandi/chinmay/blob/chinmay/autocar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv('/content/auto_mpg_sample.csv')
df
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   27.6          3          94.4       181.8    4989          16.5
# 1   28.2          3         380.8         NaN    2608          18.6
# 2   33.4          3         303.3       171.7    2939          14.7
# 3   36.3          8         294.1       183.7    3563          12.5
# 4   34.1          5         287.1       225.6    1712          17.0
# 5   11.3          4          77.5         NaN    3239          10.3
# 6   27.4          5         311.5       122.1    4358          10.4
# 7   15.1          8         254.7       199.0    3558          14.9
# 8   30.4          8         148.2         NaN    2505          13.6
# 9   14.8          5         149.0        87.1    2499          10.8
# 10  32.6          5         115.1       220.0    2102          16.7
# 11  35.4          5         376.4        78.0    4642          11.4
# 12  36.6          4         191.3       163.1    3797          19.0
# ...

# %%
# Drop 'name' column safely
df.drop('name', axis=1, inplace=True, errors='ignore')

print("\nDataset after dropping 'name' column:")
print(df.head())
# Out:
# Dataset after dropping 'name' column:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  27.6          3          94.4       181.8    4989          16.5
# 1  28.2          3         380.8         NaN    2608          18.6
# 2  33.4          3         303.3       171.7    2939          14.7
# 3  36.3          8         294.1       183.7    3563          12.5
# 4  34.1          5         287.1       225.6    1712          17.0
#
#    model_year  origin
# 0          78   japan
# 1          76  europe
# 2          70     usa
# 3          71  europe
# 4          71     usa

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['origin']=le.fit_transform(df['origin'])
df
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   27.6          3          94.4       181.8    4989          16.5
# 1   28.2          3         380.8         NaN    2608          18.6
# 2   33.4          3         303.3       171.7    2939          14.7
# 3   36.3          8         294.1       183.7    3563          12.5
# 4   34.1          5         287.1       225.6    1712          17.0
# 5   11.3          4          77.5         NaN    3239          10.3
# 6   27.4          5         311.5       122.1    4358          10.4
# 7   15.1          8         254.7       199.0    3558          14.9
# 8   30.4          8         148.2         NaN    2505          13.6
# 9   14.8          5         149.0        87.1    2499          10.8
# 10  32.6          5         115.1       220.0    2102          16.7
# 11  35.4          5         376.4        78.0    4642          11.4
# 12  36.6          4         191.3       163.1    3797          19.0
# ...

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.fillna(df.mean(),inplace=True)
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
x=df.iloc[:, 1:8]
y=df[['mpg']]
x
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0           3          94.4  181.800000    4989          16.5          78
# 1           3         380.8  146.113636    2608          18.6          76
# 2           3         303.3  171.700000    2939          14.7          70
# 3           8         294.1  183.700000    3563          12.5          71
# 4           5         287.1  225.600000    1712          17.0          71
# 5           4          77.5  146.113636    3239          10.3          73
# 6           5         311.5  122.100000    4358          10.4          70
# 7           8         254.7  199.000000    3558          14.9          82
# 8           8         148.2  146.113636    2505          13.6          81
# 9           5         149.0   87.100000    2499          10.8          73
# 10          5         115.1  220.000000    2102          16.7          74
# 11          5         376.4   78.000000    4642          11.4          70
# ...

# %%
y
# Out:
#      mpg
# 0   27.6
# 1   28.2
# 2   33.4
# 3   36.3
# 4   34.1
# 5   11.3
# 6   27.4
# 7   15.1
# 8   30.4
# 9   14.8
# 10  32.6
# 11  35.4
# 12  36.6
# 13  34.6
# 14  22.5
# 15  16.5
# 16  31.6
# 17  21.2
# 18  23.4
# 19  22.3
# 20  15.7
# 21  38.3
# 22  13.7
# 23  36.9
# 24  19.8
# 25  14.5
# 26  18.5
# 27  11.6
# 28  18.9
# 29  30.5
# 30  33.9
# 31  15.3
# 32  20.5
# 33  14.4
# 34  20.9
# 35  11.1
# 36  11.0
# 37  13.2
# 38  35.3
# 39  23.6
# 40  33.1
# 41  22.7
# 42  36.6
# 43  23.4
# 44  12.3
# 45  38.6
# 46  31.8
# 47  23.6
# 48  33.5
# 49  15.8

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 33          4         174.6  146.700000    2603          13.0          74
# 35          5         254.8  146.700000    3228           8.5          74
# 26          6         209.2  146.113636    1690          10.7          81
# 34          5         364.4  146.700000    3845          15.9          74
# 18          8         410.9  146.113636    4189          13.2          74
# 7           8         254.7  199.000000    3558          14.9          82
# 14          4         337.7  143.800000    4273          12.5          70
# 45          3          99.0  146.700000    3076           8.4          76
# 48          3         219.2  146.700000    2171           9.7          75
# 29          3         118.1  146.700000    2025          14.6          82
# 15          4         270.0   80.300000    3414          14.4          71
# 30          4         272.5  146.700000    4012          12.6          75
# ...

# %%
x_test
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 28          5         204.2       146.7    1835          12.8          71
# 11          5         376.4        78.0    4642          11.4          70
# 10          5         115.1       220.0    2102          16.7          74
# 41          3         148.8       146.7    2305          10.6          75
# 2           3         303.3       171.7    2939          14.7          70
# 27          3         214.4       146.7    4417          11.7          77
# 38          8         405.1       146.7    3975          14.8          82
# 31          3         255.2       146.7    3634          18.4          71
# 22          3         136.1       146.7    4188          14.9          72
# 4           5         287.1       225.6    1712          17.0          71
#
#     origin
# 28       0
# 11       2
# 10       2
# 41       1
# 2        2
# 27       0
# 38       1
# 31       0
# 22       0
# 4        2

# %%
y_train
# Out:
#      mpg
# 33  14.4
# 35  11.1
# 26  18.5
# 34  20.9
# 18  23.4
# 7   15.1
# 14  22.5
# 45  38.6
# 48  33.5
# 29  30.5
# 15  16.5
# 30  33.9
# 32  20.5
# 16  31.6
# 42  36.6
# 20  15.7
# 43  23.4
# 8   30.4
# 13  34.6
# 25  14.5
# 5   11.3
# 17  21.2
# 40  33.1
# 49  15.8
# 1   28.2
# 12  36.6
# 37  13.2
# 24  19.8
# 6   27.4
# 23  36.9
# 36  11.0
# 21  38.3
# 19  22.3
# 9   14.8
# 39  23.6
# 46  31.8
# 3   36.3
# 0   27.6
# 47  23.6
# 44  12.3

# %%
y_test
# Out:
#      mpg
# 28  18.9
# 11  35.4
# 10  32.6
# 41  22.7
# 2   33.4
# 27  11.6
# 38  35.3
# 31  15.3
# 22  13.7
# 4   34.1

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print("y_pred:\n",y_pred)
# Out:
# y_pred:
#  [[22.03979263]
#  [17.15650215]
#  [27.84926826]
#  [22.7258732 ]
#  [23.48571339]
#  [24.39114589]
#  [23.77507699]
#  [26.66083367]
#  [25.61960268]
#  [26.03944347]]

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)

print("Mean Squared Error:",mse)
print("Mean Absolute Error:",mae)
print("Root Mean Squared Error:",rmse)
print("R2 Score:",r2)
# Out:
# Mean Squared Error: 109.61020170043926
# Mean Absolute Error: 9.173124381620976
# Root Mean Squared Error: 10.469489084976367
# R2 Score: -0.26232496891053136
